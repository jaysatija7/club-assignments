7\xaa\xd9\x82\xcf>e\x8bQ1"9\x17\xc8\xa2&\x9f\xb4a\x17\xcc+\xc2\xb7\xb4\xad\xaa\xfda\x97{\xaf\x1b\xa4,\x99\xa5\xd0\xf0Os\x91wU\xbb\xb0\x8d\xd5m\xdcfN&\xd7{\x19\xa3\x8d\xb1\xac7XtT\x14\xcc6\xeaM\x83\xf0|6\xdf<\xc8\xc1\x86u\xc1\xe5)\x89\x95.yzo\x8f\xe2\xa3m\xf0\xdd\xb2\xe1\xcch\xc8\xdaz\xcf=\'\r\xca\xa6\xb7\xd9\xfb\x80W\xb1o\xb5>\x0f\xe3)\xa2\xab\'\xa0\xef7\xabb0\xc3i]G^\xc3l\xe6|/[E\x91&\xa4\x00\x12\xacph\xe8\x85\xde\x9f*u;\x12\x02e\x01\x7f,\xd9u\x0b[|\x88\xc4?J\xffz/\xbc\x0eJs\xdd\xdd%<\x81\x81\x02\xb8\xb5\x85\x93z:\x8f\x9fj\xec\xef\x9f\xe5\x1e=Q\xeb\x9c]\xfe\x80\x85+vlY\x17t\xd4\xe8\xb0\xe4\xd3\x0f|(\xc8\xef\xab\x96}\xf1\xc6O\x0e\x16\xe0g\xafy\xa09\xdd{O%\xa7\xa4\xc7Px\x9b{E\xbd\xe5\xfat\xf4\xb6\xc7\xcb\xb0\x80\xa7w\x81U\xdeo\xe0#\xec\xe1\x82\xa7\xbb\xc0\x1e\xf7\x82\xfe\xe2)\xae\x9 ...

# %%
# !ls
# Out:
# datasets.zip  sample_data

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Series
# You can think of a Series as a “column” of data, such as a collection of observations on a single variable.

# %%
s = pd.Series(np.random.randn(4))          # create the panda data type series
s
# Out:
# 0   -0.050339
# 1   -1.285334
# 2   -0.511603
# 3    1.178055
# dtype: float64

# %%
s.describe()           # Generate descriptive statistics
# Out:
# count    4.000000
# mean     0.008907
# std      0.931814
# min     -0.801529
# 25%     -0.677091
# 50%     -0.193071
# 75%      0.492927
# max      1.223299
# dtype: float64

# %% [markdown]
# # DataFrames
# While a Series is a single column of data, a DataFrame is several columns, one for each variable.
#
# It is a powerful tool for representing and analyzing data that are naturally organized  into rows and columns, often with  descriptive indexes for individual rows and individual columns.

# %%
df = pd.read_csv('/mobile-cleaned.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()         # Provides a look over the first 5 entries in our data
# Out:
#    sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0         0        12        55  ...              2000             125         1
# 1         0         1        55  ...              2000             165         1
# 2         0         9        55  ...              2500             164         0
# 3         0         8        55  ...              3000             165         1
# 4         1         1        55  ...              3000             165         0
#
# [5 rows x 40 columns]

# %%
df.tail()         # Provides a look over the last 5 entries in our data
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 104         3        10        14  ...              3410               8         1
# 105         0         5         3  ...              3600             101         1
# 106         3        10         6  ...              2750               1         1
# 107         3        10        12  ...              1810               7         1
# 108         2         8         3  ...              3000               2         0
#
# [5 rows x 40 columns]

# %%
dir(df)          # return an alphabetized list of names comprising (some of) the attributes of the given object
# Out:
# ['FM',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_add_series_or_dataframe_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_align_frame',
#  '_align_series',
#  '_box_col_values',
#  '_box_item_values',
#  '_builtin_table',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_combine_frame',
#  '_combine_match_index',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_dict_from',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_create_indexer',
#  '_cython_table',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_from_arrays',
#  '_from_axes',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_cython_func',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_get_values',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_iget_item_cache',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_internal_get_values',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cached',
#  '_is_copy',
#  '_is_datelike_mixed_type',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_numeric_mixed_type',
#  '_is_view',
#  '_ix',
#  '_ixs',
#  '_join_compat',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_obj_with_exclusions',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_series',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_is_copy',
#  '_set_item',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_setup_axes',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_try_aggregate_string_function',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  '_xs',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'aperture',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'auto_focus',
#  'axes',
#  'battery_capacity',
#  'battery_type',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'brand_rank',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'display_resolution',
#  'display_type',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expandable_memory',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flash_type',
#  'floordiv',
#  'frames_per_second',
#  'from_dict',
#  'from_records',
#  'front_camera_resolution',
#  'ge',
#  'get',
#  'gpu_rank',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'internal_memory',
#  'interpolate',
#  'is_liked',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'micro_sd_slot',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'no_of_cores',
#  'no_of_reviews_in_gsmarena_in_week',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'os',
#  'pct_change',
#  'phone_height',
#  'phone_width',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'price',
#  'primary_camera_resolution',
#  'processor_frequency',
#  'processor_rank',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'ram_memory',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'removable_battery',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'screen_pixel_density',
#  'screen_protection',
#  'screen_size',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_index',
#  'shape',
#  'shift',
#  'sim_size',
#  'sim_type',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'stand_by_time',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'talk_time',
#  'thickness',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tshift',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'usb_type',
#  'values',
#  'var',
#  'version',
#  'video_resolution',
#  'water_proof_rate',
#  'weight',
#  'where',
#  'xs']

# %%
len(df)
# Out:
# 109

# %%
df.shape
# Out:
# (109, 40)

# %% [markdown]
# # iloc vs loc in Pandas

# %% [markdown]
# To select both rows and columns using integers, the iloc attribute can be used

# %%
df.iloc[2:5, 0:4]
# Out:
#    sim_type  aperture  gpu_rank  weight
# 2         0         9        55   142.0
# 3         0         8        55   152.0
# 4         1         1        55   234.0

# %% [markdown]
# To select rows and columns using a mixture of integers and labels, the loc attribute can be used

# %%
df.loc[4:7]
# Out:
#    sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 4         1         1        55  ...              3000             165         0
# 5         0        14        55  ...              2900             165         0
# 6         1         1        56  ...              1700             163         1
# 7         0         8        41  ...              2000              92         1
#
# [4 rows x 40 columns]

# %%
df.loc[4:7, ['gpu_rank', 'processor_frequency']]
# Out:
#    gpu_rank  processor_frequency
# 4        55                  1.3
# 5        55                  1.3
# 6        56                  1.3
# 7        41                  1.0

# %% [markdown]
# # More in Pandas

# %% [markdown]
# Selecting particular rows using standard Python array slicing notation and creating a new dataframe object from it

# %%
df.isnull()
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0       False     False     False  ...             False           False     False
# 1       False     False     False  ...             False           False     False
# 2       False     False     False  ...             False           False     False
# 3       False     False     False  ...             False           False     False
# 4       False     False     False  ...             False           False     False
# ..        ...       ...       ...  ...               ...             ...       ...
# 104     False     False     False  ...             False           False     False
# 105     False     False     False  ...             False           False     False
# 106     False     False     False  ...             False           False     False
# 107     False     False     False  ...             False           False     False
# 108     False     False     False  ...             False           False     False
#
# [109 rows x 40 columns]

# %%
df.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# primary_camera_resolution            0
# battery_type                         0
# ram_memory                           0
# internal_memory                      0
# brand_rank                           0
# no_of_cores                          0
# micro_sd_slot                        0
# screen_pixel_density                 0
# water_proof_rate                     0
# phone_width                          0
# expandable_memory                    0
# version                              0
# usb_type                             0
# battery_capacity                     0
# processor_rank                       0
# is_liked                             0
# dtype: int64

# %%
df_short = df[25:30]

# %%
df_short.shape
# Out:
# (5, 40)

# %%
df_short.head()
# Out:
#     sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 25         0         8        43  ...              5000              94         1
# 26         0         8        43  ...              3000              94         1
# 27         0         8        38  ...              3000              19         1
# 28         0         1        44  ...              2100              79         1
# 29         0        10        43  ...              3100              94         1
#
# [5 rows x 40 columns]

# %%
df_short = df_short.set_index('thickness')     # Change the index
df_short
# Out:
#            sim_type  aperture  ...  processor_rank  is_liked
# thickness                      ...
# 10.6              0         8  ...              94         1
# 10.8              0         8  ...              94         1
# 9.3               0         8  ...              19         1
# 9.6               0         1  ...              79         1
# 9.4               0        10  ...              94         1
#
# [5 rows x 39 columns]

# %%
df_thin = df[['stand_by_time', 'expandable_memory', 'price', 'battery_capacity', 'is_liked']]

# %%
df_thin.shape
# Out:
# (109, 5)

# %%
df_thin.head()
# Out:
#    stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 0            250               64.0   3870              2000         1
# 1            300               32.0   4059              2000         1
# 2            329               32.0   4777              2500         0
# 3            385               32.0   5799              3000         1
# 4            385               32.0   5990              3000         0

# %%
df_liked = df_thin[df_thin['is_liked'] == 1]

# %%
df_liked.shape
# Out:
# (92, 5)

# %%
df_thin.describe()
# Out:
#        stand_by_time  expandable_memory  ...  battery_capacity    is_liked
# count      109.00000         109.000000  ...        109.000000  109.000000
# mean       404.66055         104.513761  ...       2841.779817    0.844037
# std        176.44206         275.799767  ...        655.003963    0.364496
# min        160.00000           0.000000  ...       1560.000000    0.000000
# 25%        264.00000           0.000000  ...       2470.000000    1.000000
# 50%        360.00000          32.000000  ...       2900.000000    1.000000
# 75%        500.00000         128.000000  ...       3100.000000    1.000000
# max       1093.00000        2048.000000  ...       5000.000000    1.000000
#
# [8 rows x 5 columns]

# %%
df_thin['price'].describe()
# Out:
# count      109.000000
# mean     19373.211009
# std      14039.197220
# min       3870.000000
# 25%       8999.000000
# 50%      14614.000000
# 75%      24999.000000
# max      64500.000000
# Name: price, dtype: float64

# %%
df_thin[df_thin['is_liked'] == 1]['price'].mean()
# Out:
# 19393.239130434784

# %%
df_thin[df_thin['is_liked'] == 0]['price'].mean()
# Out:
# 19264.823529411766

# %%
g = df_thin.groupby(['is_liked'])

# %%
for key, df_key in g:
  print(key)
  print(df_key)
# Out:
# 0
#      stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 2              329               32.0   4777              2500         0
# 4              385               32.0   5990              3000         0
# 5              280               32.0   5999              2900         0
# 11             300              128.0   6990              2600         0
# 22             354              128.0   7999              2400         0
# 38             490               32.0   9999              2100         0
# 53             345               64.0  14300              2950         0
# 60             840                0.0  15689              4100         0
# 74             390              128.0  21999              2800         0
# 77             620              128.0  22999              3100         0
# 78             618                0.0  24499              3600         0
# 80             598                0.0  24999              3000         0
# 83             504              200.0  25500              2600         0
# 90             500                0.0  34999              3760         0
# 91             240                0.0  34999              1624         0
# 95             580              256.0  37766              2840         0
# 108            400                0.0  27999              3000         0
# 1
#      stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 0              250               64.0   3870              2000         1
# 1              300               32.0   4059              2000         1
# 3              385               32.0   5799              3000         1
# 6              230              128.0   5999              1700         1
# 7              182               32.0   6599              2000         1
# ..             ...                ...    ...               ...       ...
# 103            600              256.0  52699              3430         1
# 104            540              256.0  54900              3410         1
# 105            400              200.0  56900              3600         1
# 106            384                0.0  59000              2750         1
# 107            250                0.0  64500              1810         1
#
# [92 rows x 5 columns]

# %%
df_thin.groupby(['is_liked']).describe()
# Out:
#          stand_by_time                          ... battery_capacity
#                  count        mean         std  ...              50%     75%     max
# is_liked                                        ...
# 0                 17.0  457.235294  157.094927  ...           2900.0  3000.0  4100.0
# 1                 92.0  394.945652  178.876246  ...           2900.0  3100.0  5000.0
#
# [2 rows x 32 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['price'],df['gpu_rank'], "bo")
plt.show()

# %% [markdown]
# ## Final words
# Thanks to all the bloggers and developers from where I compiled all the resources.
# Some useful refrences but not limited to:
# 1. [Pandas - Python Programming for Economics](https://python-programming.quantecon.org/pandas.html)
# 2. [What is Pandas? Why and How to Use Pandas in Python](https://www.youtube.com/watch?v=dcqPhpY7tWk)

# %% [markdown]
# Questions you should try out(dataset will be provided to you):
# 1.  Display the dataset (5 rows only)
# 2.  Display column `ParentId`
# 3.  Access 3rd row's 1st column
# 4. Display rows with  index number 7 to index number 18
# 5. Display rows where column'SomeBool' = `true`

# %%
adf = pd.read_csv('/dataset-for-assignment.csv')
adf.head()
# Out:
#    Id  ParentId  ... SomeCountry MixedStringNumber
# 0   1      62.0  ...          AL                21
# 1   2       NaN  ...          AL               NaN
# 2   3      45.0  ...          AL                21
# 3   4      38.0  ...          AL               NaN
# 4   5       NaN  ...          AL      0.4080873354
#
# [5 rows x 14 columns]

# %%
adf['ParentId']
# Out:
# 0      62.0
# 1       NaN
# 2      45.0
# 3      38.0
# 4       NaN
#        ...
# 994    42.0
# 995    48.0
# 996     NaN
# 997     NaN
# 998     NaN
# Name: ParentId, Length: 999, dtype: float64

# %%
adf.iloc[3,1]
# Out:
# 38.0

# %%
adf.loc[7:18]
# Out:
#     Id  ParentId  ... SomeCountry MixedStringNumber
# 7    8       NaN  ...          AL      0.8039496467
# 8    9       NaN  ...          AL                29
# 9   10      68.0  ...          AL                16
# 10  11       NaN  ...          AL      0.7261631249
# 11  12      74.0  ...          AL      0.2942268336
# 12  13       NaN  ...          AL       0.342712034
# 13  14       NaN  ...          AL               NaN
# 14  15      64.0  ...          AL      0.6301374716
# 15  16       NaN  ...          AL       test-string
# 16  17       NaN  ...          AL                 8
# 17  18       NaN  ...          AL      0.7033938425
# 18  19       NaN  ...          AL      0.6950933348
#
# [12 rows x 14 columns]

# %%
new_df = adf[adf['SomeBoolean'] == True]
new_df
# Out:
#       Id  ParentId  ... SomeCountry MixedStringNumber
# 0      1      62.0  ...          AL                21
# 1      2       NaN  ...          AL               NaN
# 2      3      45.0  ...          AL                21
# 3      4      38.0  ...          AL               NaN
# 4      5       NaN  ...          AL      0.4080873354
# ..   ...       ...  ...         ...               ...
# 986  987      41.0  ...         NaN               NaN
# 987  988       NaN  ...         NaN                18
# 988  989       NaN  ...         NaN       0.584634822
# 993  994       NaN  ...         NaN                19
# 996  997       NaN  ...         NaN    0.002558429094
#
# [457 rows x 14 columns]
